# %% [markdown]
# # Data Cleaning
#
# * Common theme of doing things in parallel.
# * Have your data in flat dataframe, sorted by ticker then date.
# * To do operations, use groupby > apply > lambda > assign paradigm.
# * Grouping by date is cross-sectional.
# * Grouping by asset is time-based.

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
sns.set_style('whitegrid')
warnings.simplefilter(action='ignore', category=FutureWarning)


perps = pd.read_csv('binance_perp_daily.csv')

# %% [markdown]
# ## Remove Stablecoins

# %%
url = "https://stablecoins.llama.fi/stablecoins?includePrices=true"
response = requests.get(url)
data = response.json()
stables = pd.Series([asset["symbol"] + 'USDT' for asset in data["peggedAssets"]]+['FTTUSDT'])
perps = perps[~perps['ticker'].str.match('|'.join([f'{s}' for s in stables]))]

# %%
perps
# Out:
#           ticker        date         open         high          low  \
# 0        BTCUSDT  2019-09-11  10172.13000  10293.11000   9884.31000
# 1        BTCUSDT  2019-09-12   9992.18000  10365.15000   9934.11000
# 2        BTCUSDT  2019-09-13  10327.25000  10450.13000  10239.42000
# 3        BTCUSDT  2019-09-14  10294.81000  10396.40000  10153.51000
# 4        BTCUSDT  2019-09-15  10355.61000  10419.97000  10024.81000
# ...          ...         ...          ...          ...          ...
# 187246   ZECUSDT  2024-02-13     20.56000     21.25000     20.24000
# 187247   ZENUSDT  2024-02-13      7.80000      8.11300      7.69000
# 187248  ZETAUSDT  2024-02-13      1.99680      2.56770      1.96300
# 187249   ZILUSDT  2024-02-13      0.02118      0.02168      0.02072
# 187250   ZRXUSDT  2024-02-13      0.32180      0.33090      0.31670
#
#               close  dollar_volume  num_trades  taker_buy_volume  \
# 0        9991.84000   8.595537e+07       10928      5.169153e+03
# 1       10326.58000   1.572235e+08       19384      1.182298e+04
# 2       10296.57000   1.890551e+08       25370      9.198551e+03
# 3       10358.00000   2.060313e+08       31494      9.761462e+03
# 4       10306.37000   2.113269e+08       27512      7.418716e+03
# ...             ...            ...         ...               ...
# 187246     20.76000   1.983711e+07      118557      4.670214e+05
# 187247      7.84000   1.378516e+07      142261      8.047045e+05
# 187248      2.36690   5.801275e+08     2860266      1.290890e+08
# 187249      0.02114   1.743621e+07      100150      3.913855e+08
# 187250      0.32400   1.655619e+07      106779      2.419653e+07
#
#         taker_buy_quote_volumne  funding_rate
# 0                  5.211008e+07     -0.000300
# 1                  1.198100e+08     -0.000300
# 2                  9.498347e+07     -0.000300
# 3                  1.004821e+08     -0.000300
# 4                  7.657771e+07     -0.000300
# ...                         ...           ...
# 187246             9.744039e+06     -0.000775
# 187247             6.405251e+06     -0.000846
# 187248             2.908471e+08     -0.000784
# 187249             8.340769e+06     -0.000919
# 187250             7.869266e+06     -0.001053
#
# [186128 rows x 11 columns]

# %% [markdown]
# ## Coins by Volume
#
# * First groupby ticker, then calculate trailing volume.
# * Then groupby date, rank it, filter by rank.
# * Again, groupby-apply-lambda-assign.
# * Dynamic universe selection at each point-in-time with a flat dataframe.

# %%
trading_universe_size = 30

# Group by ticker, calculate trailing 30-day volume, and filter out NA values
universe = perps.groupby('ticker') \
    .apply(lambda x: x.assign(trail_volume=x['dollar_volume'].rolling(window=30).mean())) \
    .dropna() \
    .groupby('date') \
    .apply(lambda x: x.assign(volume_rank=x['trail_volume'].rank(ascending=False),
                              is_universe=x['trail_volume'].rank(ascending=False) <= trading_universe_size))

# Group by date and is_universe, summarize count, and reset index
universe_counts = universe.groupby(['date', 'is_universe']).size().reset_index(name='count')

# Plot
plt.figure(figsize=(7, 3.5))
plt.plot(universe_counts[universe_counts['is_universe']]['date'], 
         universe_counts[universe_counts['is_universe']]['count'], 
         label='In Universe', color='blue')
plt.plot(universe_counts[~universe_counts['is_universe']]['date'], 
         universe_counts[~universe_counts['is_universe']]['count'], 
         label='Outside Universe', color='red')
plt.title('Universe Size')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.xticks([])  # Hide x-axis ticks
plt.show()

original_universe = universe.copy()
# reset our index to be sorted by ticker then date and filter our universe to keep only our top 30
universe = universe[universe.is_universe==True].sort_values(['ticker','date']).reset_index(drop=True)

# %% [markdown]
# ## Returns

# %%
universe = universe.groupby('ticker')        \
                   .apply(lambda x:x         \
                   .assign(                  \
                    rets = (x['funding_rate'] + (universe['close'] - x['close'].shift()) / x['close'].shift()).shift(-1)
                   ))                        \
                   .dropna()

universe['log_rets'] = np.log(1+universe.rets)

# %% [markdown]
# # Features

# %% [markdown]
# ## Feature Creation

# %%
features = universe.groupby('ticker') \
    .apply(lambda x: x.assign( \
        breakout=(9.5 - x['close'].rolling(20).apply(lambda x: x.index.values.max()-x.idxmax())).shift(),
        momo=x['close'].sub(x['close'].shift(10)).div(x['close'].shift(10)).shift(),
        carry=x['funding_rate'].shift()
        )) \
    .reset_index(drop=True) \
    .dropna()

# %%
features
# Out:
#              ticker        date      open      high       low     close  \
# 20     1000BONKUSDT  2024-01-10  0.013108  0.016830  0.012529  0.013504
# 21     1000BONKUSDT  2024-01-11  0.013501  0.017969  0.013404  0.016869
# 22     1000BONKUSDT  2024-01-12  0.016870  0.017024  0.014135  0.014188
# 23     1000BONKUSDT  2024-01-13  0.014193  0.014681  0.013000  0.013630
# 24     1000BONKUSDT  2024-01-14  0.013630  0.015617  0.013429  0.015087
# ...             ...         ...       ...       ...       ...       ...
# 42609       ZRXUSDT  2020-09-17  0.440700  0.453000  0.423400  0.435400
# 42610       ZRXUSDT  2020-09-18  0.435800  0.442500  0.425900  0.429800
# 42611       ZRXUSDT  2020-09-19  0.429900  0.430000  0.403800  0.418500
# 42612       ZRXUSDT  2020-09-20  0.418600  0.429300  0.403300  0.406100
# 42613       ZRXUSDT  2022-05-06  0.691100  0.738400  0.676400  0.711900
#
#        dollar_volume  num_trades  taker_buy_volume  taker_buy_quote_volumne  \
# 20      8.297512e+08     4130793      2.845306e+10             4.122173e+08
# 21      6.998983e+08     3377516      2.228633e+10             3.489968e+08
# 22      3.341155e+08     1693247      1.033307e+10             1.623714e+08
# 23      2.821651e+08     1554499      1.005612e+10             1.382115e+08
# 24      3.200448e+08     1789355      1.072325e+10             1.589151e+08
# ...              ...         ...               ...                      ...
# 42609   5.020153e+06       41478      5.529820e+06             2.433675e+06
# 42610   4.375329e+06       31994      4.728861e+06             2.057155e+06
# 42611   3.750271e+06       30323      4.298633e+06             1.789655e+06
# 42612   3.136041e+06       35017      3.650260e+06             1.531966e+06
# 42613   9.266866e+07      340881      6.617395e+07             4.659946e+07
#
#        funding_rate  trail_volume  volume_rank  is_universe      rets  \
# 20        -0.000326  6.033158e+08          8.0         True  0.248885
# 21        -0.000300  6.128281e+08          8.0         True -0.159476
# 22        -0.000545  6.072890e+08          9.0         True -0.039629
# 23        -0.000300  5.807903e+08         10.0         True  0.107495
# 24         0.000598  4.601512e+08         15.0         True -0.093427
# ...             ...           ...          ...          ...       ...
# 42609     -0.000300  2.924804e+07         20.0         True -0.013162
# 42610     -0.000300  2.829918e+07         21.0         True -0.026854
# 42611     -0.000562  2.772800e+07         21.0         True -0.030249
# 42612     -0.000619  1.883410e+07         30.0         True  0.753031
# 42613      0.000015  1.860478e+08         30.0         True -0.025740
#
#        log_rets  breakout      momo     carry
# 20     0.222251      -5.5 -0.105188 -0.000121
# 21    -0.173729      -6.5 -0.048880 -0.000326
# 22    -0.040436      -7.5  0.235462 -0.000300
# 23     0.102100      -8.5  0.026777 -0.000545
# 24    -0.098083      -9.5  0.137540 -0.000300
# ...         ...       ...       ...       ...
# 42609 -0.013249      -8.5 -0.016734 -0.000300
# 42610 -0.027221      -9.5 -0.023110 -0.000300
# 42611 -0.030716      -9.5 -0.024733 -0.000300
# 42612  0.561346      -9.5 -0.081633 -0.000562
# 42613 -0.026077      -9.5 -0.164059 -0.000619
#
# [39551 rows x 19 columns]

# %% [markdown]
# ## Feature Exploration

# %%
# Plot using Seaborn
fig, ax = plt.subplots(1,3, figsize=(13,3))
ax.flatten()

# Create separate subplots for each feature type
for i, feature in enumerate(['breakout', 'momo', 'carry']):
    features[feature].plot(kind='hist', bins=200, ax=ax[i], title=f'{feature}')

plt.show()

# %% [markdown]
# ## Feature Standardization

# %%
scaled_features = features.groupby('date').apply(lambda x:x.assign(
                  demeaned_rets = x.log_rets - x.log_rets.mean(),
                  z_carry = (x.carry - x.carry.mean())/x.carry.std(),
                  decile_carry = pd.qcut(x.carry.rank(method='first'), q=10, labels=False, duplicates='drop') + 1,
                  z_momo = (x.momo - x.momo.mean())/x.momo.std(),
                  decile_momo = pd.qcut(x.momo.rank(method='first'), q=10, labels=False, duplicates='drop') + 1,
                  z_breakout = (x.breakout - x.breakout.mean())/x.breakout.std()
)).reset_index(drop=True)

# Drop rows with NaN values
scaled_features = scaled_features.dropna()

# %%
# Plot using Seaborn
fig, ax = plt.subplots(1,3, figsize=(13,3))
ax.flatten()

# Create separate subplots for each feature type
for i, feature in enumerate(['z_breakout', 'z_momo', 'z_carry']):
    scaled_features[feature].plot(kind='hist', bins=200, ax=ax[i], title=f'{feature}')

plt.show()

# %% [markdown]
# ## Feature Deciles

# %%
scaled_features.groupby('decile_carry').demeaned_rets.mean().plot(kind='bar', title='Carry decile vs next-day cross-sectional return', figsize=(10,3),rot=0)
# Out:
# <AxesSubplot: title={'center': 'Carry decile vs next-day cross-sectional return'}, xlabel='decile_carry'>

# %%
scaled_features.groupby('decile_momo').demeaned_rets.mean().plot(kind='bar', title='Momo decile vs next-day cross-sectional return', figsize=(10,3),rot=0)
# Out:
# <AxesSubplot: title={'center': 'Momo decile vs next-day cross-sectional return'}, xlabel='decile_momo'>

# %%
scaled_features.groupby('breakout').log_rets.mean().plot(kind='bar', title='Breakout vs next-day mean return', figsize=(10,3),rot=0)
# Out:
# <AxesSubplot: title={'center': 'Breakout vs next-day mean return'}, xlabel='breakout'>

# %% [markdown]
# ## Signal IC
#
# * Pandas
#     * For pandas, effective use of `melt` to long form, then `groupby`-`apply`-`lambda`.
#     * For `melt`,`id_vars` remain unchanged, `value_vars` will be the column names melted into single column. Their `value_name` is the singular column of their values.
#     * Once done, easy to `groupby`. `apply` a `lambda` function to return a series, for each group of correlation.
# * Features
#     * Carry is clearly the strongest predictive feature of forward demeaned returns.
#     * Momo shows the slight mean reversion effect.

# %%
# Assuming 'features_scaled' DataFrame is already defined

# Melt the DataFrame to long format
melted_features = pd.melt(scaled_features, id_vars=['date', 'ticker', 'is_universe', 'demeaned_rets'], 
                           value_vars=['breakout', 'z_carry', 'z_momo', 'decile_carry', 'decile_momo'], 
                           var_name='feature', value_name='value')

# Calculate Information Coefficient (IC)
ic_data = melted_features.groupby('feature').apply(lambda x: pd.Series({'IC': x['value'].corr(x['demeaned_rets'])})).reset_index()


# Plot using Seaborn
plt.figure(figsize=(9, 3))
sns.barplot(x='feature', y='IC', data=ic_data, order=['breakout', 'z_carry', 'decile_carry', 'z_momo', 'decile_momo'], palette='viridis')

# Set labels and title
plt.xlabel('Feature')
plt.ylabel('IC')
plt.title('Relative Return Information Coefficient')

plt.show()

# %%
# Assuming 'features_scaled' DataFrame is already defined

# Melt the DataFrame to long format
melted_features = pd.melt(scaled_features, id_vars=['date', 'ticker', 'is_universe', 'log_rets'], 
                           value_vars=['breakout', 'z_carry', 'z_momo', 'decile_carry', 'decile_momo'], 
                           var_name='feature', value_name='value')


# Calculate Information Coefficient (IC)
ic_data = melted_features.groupby('feature').apply(lambda x: pd.Series({'IC': x['value'].corr(x['log_rets'])})).reset_index()


# Plot using Seaborn
plt.figure(figsize=(9, 3))
sns.barplot(x='feature', y='IC', data=ic_data, order=['breakout', 'z_carry', 'decile_carry', 'z_momo', 'decile_momo'], palette='viridis')

# Set labels and title
plt.xlabel('Feature')
plt.ylabel('IC')
plt.title('Absolute Return Information Coefficient')

plt.show()

# %% [markdown]
# ## Signal Decay (Forward IC)
#
# * Pandas
#     * Same workflow as above, `melt` with `groupby` but a double `melt`, then a `lineplot` with `hue` by `feature`.
# * Features
#     * Original plot has sticky IC for carry (but lower starting point), slower decay. Maybe because of my universe selection.
#     * Momo starts with negative IC.
#     * Breakout has very sticky IC in time series return.

# %%
forward_periods = range(2, 8)
for i in forward_periods:
    scaled_features[f'demeaned_rets_{i}'] = scaled_features.groupby('ticker')['demeaned_rets'].shift(-i)

# Melt the DataFrame to long format
melted_features = pd.melt(scaled_features, id_vars=['date', 'ticker', 'is_universe', 'demeaned_rets'] + [f'demeaned_rets_{i}' for i in range(2,8)], 
                           value_vars=['z_carry', 'z_momo', 'decile_carry', 'decile_momo'], 
                           var_name='feature', value_name='value')

melted_melted_features = pd.melt(melted_features, id_vars=['feature','value'],
                          value_vars=['demeaned_rets']+[f'demeaned_rets_{i}' for i in range(2,8)],
                          var_name='lookahead',value_name='rets')

ic_data = melted_melted_features.groupby(['feature', 'lookahead']).apply(
    lambda x: pd.Series({'IC': x['value'].corr(x['rets'])})
).reset_index()

# %%
fig, ax = plt.subplots(figsize=(10,4))
sns.lineplot(data=ic_data, x='lookahead', y='IC', hue='feature', style='feature', markers=True, ax=ax, markersize=8, palette='viridis')
plt.title('IC by forward period (days) against relative returns')
plt.xlabel('Forward Period')
plt.show()

# %%
forward_periods = range(2, 8)
for i in forward_periods:
    scaled_features[f'log_rets_{i}'] = scaled_features.groupby('ticker')['log_rets'].shift(-i)

# Melt the DataFrame to long format
melted_features = pd.melt(scaled_features, id_vars=['date', 'ticker', 'is_universe', 'log_rets'] + [f'log_rets_{i}' for i in range(2,8)], 
                           value_vars=['breakout'], 
                           var_name='feature', value_name='value')

melted_melted_features = pd.melt(melted_features, id_vars=['feature','value'],
                          value_vars=['log_rets']+[f'log_rets_{i}' for i in range(2,8)],
                          var_name='lookahead',value_name='rets')

ic_data = melted_melted_features.groupby(['feature', 'lookahead']).apply(
    lambda x: pd.Series({'IC': x['value'].corr(x['rets'])})
).reset_index()

# %%
fig, ax = plt.subplots(figsize=(10,3))
sns.lineplot(data=ic_data, x='lookahead', y='IC', hue='feature', style='feature', markers=True, ax=ax, markersize=8)
plt.title('IC by forward period (days) against relative returns')
plt.xlabel('Forward Period')
plt.show()

# %% [markdown]
# ## Signal Correlation
#
# * Carry is negatively correlated with breakout and momo.
# * Most features have quite low correlations.

# %%
pure_features = scaled_features[['breakout','momo','decile_momo','z_momo','carry','decile_carry','z_carry']]

# Calculate the correlation matrix
correlation_matrix = pure_features.corr()
matrix = np.triu(correlation_matrix).T - np.diag(v=[1,1,1,1,1,1,1])

# Plot the correlation matrix using seaborn's heatmap
plt.figure(figsize=(8,3))
sns.heatmap(correlation_matrix, annot=True, cmap='crest_r', fmt='.2f', linewidths=.5, vmin=-0.1,vmax=0.5, mask=matrix)

# Set the title
plt.title('Correlation Matrix')

# Show the plot
plt.show()

# %% [markdown]
# # Combining Signals
#
# * Pandas
#     * `transform` vs `apply`: they do the same thing, but the former will _broadcast_ result, the latter will _reduce_.
#     * Instead of `groupby`-`apply`-`lambda`-`assign`, we can `assign`-`transform`.
#     * The procedure takes deciles (1-10), and centers them about 0.
# * Weights
#     * Overweights carry (high IC), negatively correlated with momo/breakout.
#     * Underweight momo (low IC)
#     * Overweight breakout slightly. Since it is weighted by time-series not cross-section, there is a net tilt effect (E.g if high breakouts for all the perps then will net long)
# * Returns
#     * Not a backtest, it says plots returns to combined features if you could do so frictionlessly.
# * Lookahead
#     * Apparently

# %% [markdown]
# ## Model

# %%
min_trading_universe_size = 3

# Find the start date based on the minimum trading universe size
start_date = (
    scaled_features.groupby(['date', 'is_universe'])
    .size()
    .reset_index(name='count')
    .query('count >= @min_trading_universe_size')
    .sort_values('date')
    .iloc[0]['date']
)

# Filter and preprocess the DataFrame for modeling using assign
model_df = (
    scaled_features\
    [['ticker','date','close','funding_rate','z_carry','momo','log_rets','demeaned_rets','is_universe','decile_carry','decile_momo','breakout']]
    .query('is_universe and date >= @start_date')
    .assign(
        carry_weight=lambda x: x['decile_carry'] - 5.5,
        momo_weight=lambda x: (x['decile_momo'] - 5.5),
        breakout_weight=lambda x: x['breakout'] / 2,
        combined_weight=lambda x: 0.5 * x['carry_weight'] + 0.2 * x['momo_weight'] + 0.3 * x['breakout_weight'])  
    ) \
    .groupby('date').apply(lambda x:x.assign( scaled_weight = np.where(x.combined_weight==0,0,x.combined_weight/x.combined_weight.abs().sum()))) \
    .groupby('date').apply(lambda x:x.assign(  
                                            scaled_carry_weight = np.where(x.carry_weight==0,0,x.carry_weight/x.combined_weight.abs().sum()),
                                            scaled_momo_weight = np.where(x.momo_weight==0,0,x.momo_weight/x.combined_weight.abs().sum()),
                                            scaled_breakout_weight = np.where(x.breakout_weight==0,0,x.breakout_weight/x.combined_weight.abs().sum())
                                             ))\

# %%
model_df
# Out:
#              ticker        date     close  funding_rate     carry      momo  \
# 0      1000BONKUSDT  2024-01-10  0.013504     -0.000326 -0.000121 -0.105188
# 1      1000BONKUSDT  2024-01-11  0.016869     -0.000300 -0.000326 -0.048880
# 2      1000BONKUSDT  2024-01-12  0.014188     -0.000545 -0.000300  0.235462
# 3      1000BONKUSDT  2024-01-13  0.013630     -0.000300 -0.000545  0.026777
# 4      1000BONKUSDT  2024-01-14  0.015087      0.000598 -0.000300  0.137540
# ...             ...         ...       ...           ...       ...       ...
# 39546       ZRXUSDT  2020-09-17  0.435400     -0.000300 -0.000300 -0.016734
# 39547       ZRXUSDT  2020-09-18  0.429800     -0.000300 -0.000300 -0.023110
# 39548       ZRXUSDT  2020-09-19  0.418500     -0.000562 -0.000300 -0.024733
# 39549       ZRXUSDT  2020-09-20  0.406100     -0.000619 -0.000562 -0.081633
# 39550       ZRXUSDT  2022-05-06  0.711900      0.000015 -0.000619 -0.164059
#
#        log_rets  demeaned_rets  is_universe  decile_carry  decile_momo  \
# 0      0.222251       0.130040         True          10.0          5.0
# 1     -0.173729      -0.166064         True           1.0          6.0
# 2     -0.040436      -0.026195         True           1.0          8.0
# 3      0.102100       0.096479         True           1.0          7.0
# 4     -0.098083      -0.069609         True           1.0          8.0
# ...         ...            ...          ...           ...          ...
# 39546 -0.013249      -0.021160         True           6.0          4.0
# 39547 -0.027221      -0.017183         True           8.0          3.0
# 39548 -0.030716       0.003082         True           8.0          4.0
# 39549  0.561346       0.645075         True           1.0          4.0
# 39550 -0.026077      -0.026839         True           1.0          6.0
#
#        breakout  carry_weight  momo_weight  breakout_weight  combined_weight  \
# 0          -5.5           4.5         -0.5            -2.75            1.325
# 1          -6.5          -4.5          0.5            -3.25           -3.125
# 2          -7.5          -4.5          2.5            -3.75           -2.875
# 3          -8.5          -4.5          1.5            -4.25           -3.225
# 4          -9.5          -4.5          2.5            -4.75           -3.175
# ...         ...           ...          ...              ...              ...
# 39546      -8.5           0.5         -1.5            -4.25           -1.325
# 39547      -9.5           2.5         -2.5            -4.75           -0.675
# 39548      -9.5           2.5         -1.5            -4.75           -0.475
# 39549      -9.5          -4.5         -1.5            -4.75           -3.975
# 39550      -9.5          -4.5          0.5            -4.75           -3.575
#
#        scaled_weight  scaled_carry_weight  scaled_momo_weight  \
# 0           0.029977             0.101810           -0.011312
# 1          -0.065104            -0.093750            0.010417
# 2          -0.058554            -0.091650            0.050916
# 3          -0.060000            -0.083721            0.027907
# 4          -0.060824            -0.086207            0.047893
# ...              ...                  ...                 ...
# 39546      -0.026890             0.010147           -0.030441
# 39547      -0.013056             0.048356           -0.048356
# 39548      -0.009557             0.050302           -0.030181
# 39549      -0.075499            -0.085470           -0.028490
# 39550      -0.079356            -0.099889            0.011099
#
#        scaled_breakout_weight
# 0                   -0.062217
# 1                   -0.067708
# 2                   -0.076375
# 3                   -0.079070
# 4                   -0.090996
# ...                       ...
# 39546               -0.086251
# 39547               -0.091876
# 39548               -0.095573
# 39549               -0.090218
# 39550               -0.105438
#
# [39430 rows x 20 columns]

# %% [markdown]
# ## Weights and Returns

# %%
weights_plot = (
    model_df
    .groupby('date').scaled_weight
    .sum()
)

weights_plot.plot(figsize=(12,4))
# Set labels and title
plt.xlabel('Date')
plt.ylabel('Portfolio net weight')
plt.title('Portfolio Net Weight Over Time')
# Out:
# Text(0.5, 1.0, 'Portfolio Net Weight Over Time')

# %%
model_df['port_rets'] = model_df.log_rets* model_df.scaled_weight
model_df.groupby('date').port_rets.sum().cumsum().plot(figsize=(12,4))
plt.title('Combined Carry, Momentum, and Breakout Model on top 30 perps by volume')
plt.xlabel('')
plt.ylabel('Cumulative return')
# Out:
# Text(0, 0.5, 'Cumulative return')

# %%
model_df['carry_rets'] = model_df.log_rets* model_df.scaled_carry_weight
model_df['momo_rets'] = model_df.log_rets* model_df.scaled_momo_weight
model_df['breakout_rets'] = model_df.log_rets* model_df.scaled_breakout_weight

model_df.groupby('date')['carry_rets','momo_rets','breakout_rets'].sum().cumsum().plot(figsize=(12,4))

plt.title('Carry, Momentum, Breakout factor returns on top 30 perps by volume')
plt.xlabel('')
plt.ylabel('Cumulative return')
# Out:
# Text(0, 0.5, 'Cumulative return')

# %%
model_df.to_pickle('model_df.pkl')

# %% [markdown]
# # Features as Expected Returns

# %% [markdown]
# ## Factor Plots by Year

# %%
# Convert 'date' to datetime format
model_df['date'] = pd.to_datetime(model_df['date'])

# Extract the year and create a new 'Year' column
model_df['Year'] = model_df['date'].dt.year

# Group by 'momo_decile' and 'Year' and calculate mean_return
grouped_data = model_df.groupby(['decile_momo', 'Year'])['demeaned_rets'].mean().reset_index()

# Set the style for Seaborn
sns.set(style="whitegrid")

# Create a factor plot
plt.figure(figsize=(5, 1))
g = sns.catplot(x='decile_momo', y='demeaned_rets', data=grouped_data,
                col='Year', kind='bar', ci=None, height=2, aspect=2, col_wrap=3, color='tab:blue')

# Set titles and labels
g.set_axis_labels("Momo Decile", "Mean Return")
g.set_titles("Year {col_name}")

# Adjust layout
plt.subplots_adjust(top=0.9)
# g.fig.suptitle('Momentum Factor Plot by Year', fontsize=12)

# Show the plot
plt.show()

# %%
# Convert 'date' to datetime format
model_df['date'] = pd.to_datetime(model_df['date'])
# Extract the year and create a new 'Year' column
model_df['Year'] = model_df['date'].dt.year
# Group by 'momo_decile' and 'Year' and calculate mean_return
grouped_data = model_df.groupby(['decile_carry', 'Year'])['demeaned_rets'].mean().reset_index()

# Set the style for Seaborn
sns.set(style="whitegrid")

# Create a factor plot
plt.figure(figsize=(5, 1))
g = sns.catplot(x='decile_carry', y='demeaned_rets', data=grouped_data,
                col='Year', kind='bar', ci=None, height=2, aspect=2, col_wrap=3, color='tab:blue')

# Set titles and labels
g.set_axis_labels("Carry Decile", "Mean Return")
g.set_titles("{col_name}")

# Adjust layout
plt.subplots_adjust(top=0.9)
# g.fig.suptitle('Carry Factor Plot by Year', fontsize=16)

# Show the plot
plt.show()

# %%
# Convert 'date' to datetime format
model_df['date'] = pd.to_datetime(model_df['date'])
# Extract the year and create a new 'Year' column
model_df['Year'] = model_df['date'].dt.year
# Group by 'momo_decile' and 'Year' and calculate mean_return
grouped_data = model_df.groupby(['breakout', 'Year'])['log_rets'].mean().reset_index()

# Set the style for Seaborn
sns.set(style="whitegrid")

# Create a factor plot
plt.figure(figsize=(5, 1))
g = sns.catplot(x='breakout', y='log_rets', data=grouped_data,
                col='Year', kind='bar', ci=None, height=2, aspect=2, col_wrap=3, color='tab:blue')

# Set titles and labels
g.set_axis_labels("Breakout Decile", "Mean Return")
g.set_titles("Year {col_name}")

# Adjust layout
plt.subplots_adjust(top=0.9)
# g.fig.suptitle('Breakout Factor Plot by Year', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# ## Rolling Regressions
#
#
# * End result: a dataframe of regression coefficients, daily row, 2 columns (momo, carry).
# * Dataframe of coefficients, row is every 10 days (e.g 10 Jan,
#  20 Jan, 30 Jan) with coeffs. Resample and backfill. Join to model_df.
# * Iterate, calculate coefficients, append to df.
# * Some more work to convert the new data (weights and coefficients) into _expected returns_
# * Wrap backtest into Python script.

# %%
df = model_df.copy()
df = df.groupby('date').apply(lambda x:x.assign(
                  breakout_weight = pd.qcut(x.breakout_weight.rank(method='first'), q=10, labels=False, duplicates='drop') + 1 - 5.5,
)).reset_index(drop=True)

# %%
import statsmodels.api as sm


def rolling_ols(data, target_col, feature_cols, window_size=30, skip_size=5):
    
    label = 'xs' if target_col == 'demeaned_rets' else 'ts'
    results = pd.DataFrame(columns=['date'] + [f'coef_{col}' for col in feature_cols] + [f'{label}_intercept'] + [f'{label}_r2'])

    # Group the data by 'date'
    grouped_data = data.groupby('date')
    # Iterate through the unique dates with the rolling window and skip
    for i in range(0, len(grouped_data), skip_size):
        # Select the unique dates for the current window
        selected_dates = list(grouped_data.groups.keys())[i:i+window_size]
        # Extract rows for the selected dates
        window_data = data[data['date'].isin(selected_dates)]

        print(window_data.date.min())
        print(window_data.date.max())
        # Fit the OLS model
        y = window_data[target_col]
        X = sm.add_constant(window_data[feature_cols])
        model = sm.OLS(y, X).fit()
        # Extract and store the results
        results = results.append({'date': window_data.iloc[-1]['date'],
                                        **{f'coef_{col}': model.params[col] for col in feature_cols},
                                        f'{label}_intercept': model.params['const'],
                                        f'{label}_r2': model.rsquared},
                                        ignore_index=True)

    results.set_index('date', inplace=True)
    results.index = pd.to_datetime(results.index)
    return results.groupby(results.index).mean()

# %%
xs_coeffs = rolling_ols(df, 'demeaned_rets', ['carry_weight','momo_weight','breakout_weight']).resample('D').ffill()
exp_return_df = df 
exp_return_df['date'] = pd.to_datetime(exp_return_df['date'])
exp_return_df = pd.merge(exp_return_df,xs_coeffs,on='date',how='inner')
# Out:
# 2020-02-06 00:00:00
# 2020-03-06 00:00:00
# 2020-02-11 00:00:00
# 2020-03-11 00:00:00
# 2020-02-16 00:00:00
# 2020-03-16 00:00:00
# 2020-02-21 00:00:00
# 2020-03-21 00:00:00
# 2020-02-26 00:00:00
# 2020-03-26 00:00:00
# 2020-03-02 00:00:00
# 2020-03-31 00:00:00
# 2020-03-07 00:00:00
# 2020-04-05 00:00:00
# 2020-03-12 00:00:00
# 2020-04-10 00:00:00
# 2020-03-17 00:00:00
# 2020-04-15 00:00:00
# 2020-03-22 00:00:00
# 2020-04-20 00:00:00
# 2020-03-27 00:00:00
# 2020-04-25 00:00:00
# 2020-04-01 00:00:00
# 2020-04-30 00:00:00
# 2020-04-06 00:00:00
# 2020-05-05 00:00:00
# 2020-04-11 00:00:00
# 2020-05-10 00:00:00
# 2020-04-16 00:00:00
# 2020-05-15 00:00:00
# 2020-04-21 00:00:00
# 2020-05-20 00:00:00
# 2020-04-26 00:00:00
# 2020-05-25 00:00:00
# 2020-05-01 00:00:00
# 2020-05-30 00:00:00
# 2020-05-06 00:00:00
# 2020-06-04 00:00:00
# 2020-05-11 00:00:00
# 2020-06-09 00:00:00
# 2020-05-16 00:00:00
# 2020-06-14 00:00:00
# 2020-05-21 00:00:00
# 2020-06-19 00:00:00
# 2020-05-26 00:00:00
# 2020-06-24 00:00:00
# 2020-05-31 00:00:00
# 2020-06-29 00:00:00
# 2020-06-05 00:00:00
# 2020-07-04 00:00:00
# 2020-06-10 00:00:00
# 2020-07-09 00:00:00
# 2020-06-15 00:00:00
# 2020-07-14 00:00:00
# 2020-06-20 00:00:00
# 2020-07-19 00:00:00
# 2020-06-25 00:00:00
# 2020-07-24 00:00:00
# 2020-06-30 00:00:00
# 2020-07-29 00:00:00
# 2020-07-05 00:00:00
# 2020-08-03 00:00:00
# 2020-07-10 00:00:00
# 2020-08-08 00:00:00
# 2020-07-15 00:00:00
# 2020-08-13 00:00:00
# 2020-07-20 00:00:00
# 2020-08-18 00:00:00
# 2020-07-25 00:00:00
# 2020-08-23 00:00:00
# 2020-07-30 00:00:00
# 2020-08-28 00:00:00
# 2020-08-04 00:00:00
# 2020-09-02 00:00:00
# 2020-08-09 00:00:00
# 2020-09-07 00:00:00
# 2020-08-14 00:00:00
# 2020-09-12 00:00:00
# 2020-08-19 00:00:00
# 2020-09-17 00:00:00
# 2020-08-24 00:00:00
# 2020-09-22 00:00:00
# 2020-08-29 00:00:00
# 2020-09-27 00:00:00
# 2020-09-03 00:00:00
# 2020-10-02 00:00:00
# 2020-09-08 00:00:00
# 2020-10-07 00:00:00
# 2020-09-13 00:00:00
# 2020-10-12 00:00:00
# 2020-09-18 00:00:00
# 2020-10-17 00:00:00
# 2020-09-23 00:00:00
# 2020-10-22 00:00:00
# 2020-09-28 00:00:00
# 2020-10-27 00:00:00
# 2020-10-03 00:00:00
# 2020-11-01 00:00:00
# 2020-10-08 00:00:00
# 2020-11-06 00:00:00
# 2020-10-13 00:00:00
# 2020-11-11 00:00:00
# 2020-10-18 00:00:00
# 2020-11-16 00:00:00
# 2020-10-23 00:00:00
# 2020-11-21 00:00:00
# 2020-10-28 00:00:00
# 2020-11-26 00:00:00
# 2020-11-02 00:00:00
# 2020-12-01 00:00:00
# 2020-11-07 00:00:00
# 2020-12-06 00:00:00
# 2020-11-12 00:00:00
# 2020-12-11 00:00:00
# 2020-11-17 00:00:00
# 2020-12-16 00:00:00
# 2020-11-22 00:00:00
# 2020-12-21 00:00:00
# 2020-11-27 00:00:00
# 2020-12-26 00:00:00
# 2020-12-02 00:00:00
# 2020-12-31 00:00:00
# 2020-12-07 00:00:00
# 2021-01-05 00:00:00
# 2020-12-12 00:00:00
# 2021-01-10 00:00:00
# 2020-12-17 00:00:00
# 2021-01-15 00:00:00
# 2020-12-22 00:00:00
# 2021-01-20 00:00:00
# 2020-12-27 00:00:00
# 2021-01-25 00:00:00
# 2021-01-01 00:00:00
# 2021-01-30 00:00:00
# 2021-01-06 00:00:00
# 2021-02-04 00:00:00
# 2021-01-11 00:00:00
# 2021-02-09 00:00:00
# 2021-01-16 00:00:00
# 2021-02-14 00:00:00
# 2021-01-21 00:00:00
# 2021-02-19 00:00:00
# 2021-01-26 00:00:00
# 2021-02-24 00:00:00
# 2021-01-31 00:00:00
# 2021-03-01 00:00:00
# 2021-02-05 00:00:00
# 2021-03-06 00:00:00
# 2021-02-10 00:00:00
# 2021-03-11 00:00:00
# 2021-02-15 00:00:00
# 2021-03-16 00:00:00
# 2021-02-20 00:00:00
# 2021-03-21 00:00:00
# 2021-02-25 00:00:00
# 2021-03-26 00:00:00
# 2021-03-02 00:00:00
# 2021-03-31 00:00:00
# 2021-03-07 00:00:00
# 2021-04-05 00:00:00
# 2021-03-12 00:00:00
# 2021-04-10 00:00:00
# 2021-03-17 00:00:00
# 2021-04-15 00:00:00
# 2021-03-22 00:00:00
# 2021-04-20 00:00:00
# 2021-03-27 00:00:00
# 2021-04-25 00:00:00
# 2021-04-01 00:00:00
# 2021-04-30 00:00:00
# 2021-04-06 00:00:00
# 2021-05-05 00:00:00
# 2021-04-11 00:00:00
# 2021-05-10 00:00:00
# 2021-04-16 00:00:00
# 2021-05-15 00:00:00
# 2021-04-21 00:00:00
# 2021-05-20 00:00:00
# 2021-04-26 00:00:00
# 2021-05-25 00:00:00
# 2021-05-01 00:00:00
# 2021-05-30 00:00:00
# 2021-05-06 00:00:00
# 2021-06-04 00:00:00
# 2021-05-11 00:00:00
# 2021-06-09 00:00:00
# 2021-05-16 00:00:00
# 2021-06-14 00:00:00
# 2021-05-21 00:00:00
# 2021-06-19 00:00:00
# 2021-05-26 00:00:00
# 2021-06-24 00:00:00
# 2021-05-31 00:00:00
# 2021-06-29 00:00:00
# 2021-06-05 00:00:00
# 2021-07-04 00:00:00
# 2021-06-10 00:00:00
# 2021-07-09 00:00:00
# 2021-06-15 00:00:00
# 2021-07-14 00:00:00
# 2021-06-20 00:00:00
# 2021-07-19 00:00:00
# 2021-06-25 00:00:00
# 2021-07-24 00:00:00
# 2021-06-30 00:00:00
# 2021-07-29 00:00:00
# 2021-07-05 00:00:00
# 2021-08-03 00:00:00
# 2021-07-10 00:00:00
# 2021-08-08 00:00:00
# 2021-07-15 00:00:00
# 2021-08-13 00:00:00
# 2021-07-20 00:00:00
# 2021-08-18 00:00:00
# 2021-07-25 00:00:00
# 2021-08-23 00:00:00
# 2021-07-30 00:00:00
# 2021-08-28 00:00:00
# 2021-08-04 00:00:00
# 2021-09-02 00:00:00
# 2021-08-09 00:00:00
# 2021-09-07 00:00:00
# 2021-08-14 00:00:00
# 2021-09-12 00:00:00
# 2021-08-19 00:00:00
# 2021-09-17 00:00:00
# 2021-08-24 00:00:00
# 2021-09-22 00:00:00
# 2021-08-29 00:00:00
# 2021-09-27 00:00:00
# 2021-09-03 00:00:00
# 2021-10-02 00:00:00
# 2021-09-08 00:00:00
# 2021-10-07 00:00:00
# 2021-09-13 00:00:00
# 2021-10-12 00:00:00
# 2021-09-18 00:00:00
# 2021-10-17 00:00:00
# 2021-09-23 00:00:00
# 2021-10-22 00:00:00
# 2021-09-28 00:00:00
# 2021-10-27 00:00:00
# 2021-10-03 00:00:00
# 2021-11-01 00:00:00
# 2021-10-08 00:00:00
# 2021-11-06 00:00:00
# 2021-10-13 00:00:00
# 2021-11-11 00:00:00
# 2021-10-18 00:00:00
# 2021-11-16 00:00:00
# 2021-10-23 00:00:00
# 2021-11-21 00:00:00
# 2021-10-28 00:00:00
# 2021-11-26 00:00:00
# 2021-11-02 00:00:00
# 2021-12-01 00:00:00
# 2021-11-07 00:00:00
# 2021-12-06 00:00:00
# 2021-11-12 00:00:00
# 2021-12-11 00:00:00
# 2021-11-17 00:00:00
# 2021-12-16 00:00:00
# 2021-11-22 00:00:00
# 2021-12-21 00:00:00
# 2021-11-27 00:00:00
# 2021-12-26 00:00:00
# 2021-12-02 00:00:00
# 2021-12-31 00:00:00
# 2021-12-07 00:00:00
# 2022-01-05 00:00:00
# 2021-12-12 00:00:00
# 2022-01-10 00:00:00
# 2021-12-17 00:00:00
# 2022-01-15 00:00:00
# 2021-12-22 00:00:00
# 2022-01-20 00:00:00
# 2021-12-27 00:00:00
# 2022-01-25 00:00:00
# 2022-01-01 00:00:00
# 2022-01-30 00:00:00
# 2022-01-06 00:00:00
# 2022-02-04 00:00:00
# 2022-01-11 00:00:00
# 2022-02-09 00:00:00
# 2022-01-16 00:00:00
# 2022-02-14 00:00:00
# 2022-01-21 00:00:00
# 2022-02-19 00:00:00
# 2022-01-26 00:00:00
# 2022-02-24 00:00:00
# 2022-01-31 00:00:00
# 2022-03-01 00:00:00
# 2022-02-05 00:00:00
# 2022-03-06 00:00:00
# 2022-02-10 00:00:00
# 2022-03-11 00:00:00
# 2022-02-15 00:00:00
# 2022-03-16 00:00:00
# 2022-02-20 00:00:00
# 2022-03-21 00:00:00
# 2022-02-25 00:00:00
# 2022-03-26 00:00:00
# 2022-03-02 00:00:00
# 2022-03-31 00:00:00
# 2022-03-07 00:00:00
# 2022-04-05 00:00:00
# 2022-03-12 00:00:00
# 2022-04-10 00:00:00
# 2022-03-17 00:00:00
# 2022-04-15 00:00:00
# 2022-03-22 00:00:00
# 2022-04-20 00:00:00
# 2022-03-27 00:00:00
# 2022-04-25 00:00:00
# 2022-04-01 00:00:00
# 2022-04-30 00:00:00
# 2022-04-06 00:00:00
# 2022-05-05 00:00:00
# 2022-04-11 00:00:00
# 2022-05-10 00:00:00
# 2022-04-16 00:00:00
# 2022-05-15 00:00:00
# 2022-04-21 00:00:00
# 2022-05-20 00:00:00
# 2022-04-26 00:00:00
# 2022-05-25 00:00:00
# 2022-05-01 00:00:00
# 2022-05-30 00:00:00
# 2022-05-06 00:00:00
# 2022-06-04 00:00:00
# 2022-05-11 00:00:00
# 2022-06-09 00:00:00
# 2022-05-16 00:00:00
# 2022-06-14 00:00:00
# 2022-05-21 00:00:00
# 2022-06-19 00:00:00
# 2022-05-26 00:00:00
# 2022-06-24 00:00:00
# 2022-05-31 00:00:00
# 2022-06-29 00:00:00
# 2022-06-05 00:00:00
# 2022-07-04 00:00:00
# 2022-06-10 00:00:00
# 2022-07-09 00:00:00
# 2022-06-15 00:00:00
# 2022-07-14 00:00:00
# 2022-06-20 00:00:00
# 2022-07-19 00:00:00
# 2022-06-25 00:00:00
# 2022-07-24 00:00:00
# 2022-06-30 00:00:00
# 2022-07-29 00:00:00
# 2022-07-05 00:00:00
# 2022-08-03 00:00:00
# 2022-07-10 00:00:00
# 2022-08-08 00:00:00
# 2022-07-15 00:00:00
# 2022-08-13 00:00:00
# 2022-07-20 00:00:00
# 2022-08-18 00:00:00
# 2022-07-25 00:00:00
# 2022-08-23 00:00:00
# 2022-07-30 00:00:00
# 2022-08-28 00:00:00
# 2022-08-04 00:00:00
# 2022-09-02 00:00:00
# 2022-08-09 00:00:00
# 2022-09-07 00:00:00
# 2022-08-14 00:00:00
# 2022-09-12 00:00:00
# 2022-08-19 00:00:00
# 2022-09-17 00:00:00
# 2022-08-24 00:00:00
# 2022-09-22 00:00:00
# 2022-08-29 00:00:00
# 2022-09-27 00:00:00
# 2022-09-03 00:00:00
# 2022-10-02 00:00:00
# 2022-09-08 00:00:00
# 2022-10-07 00:00:00
# 2022-09-13 00:00:00
# 2022-10-12 00:00:00
# 2022-09-18 00:00:00
# 2022-10-17 00:00:00
# 2022-09-23 00:00:00
# 2022-10-22 00:00:00
# 2022-09-28 00:00:00
# 2022-10-27 00:00:00
# 2022-10-03 00:00:00
# 2022-11-01 00:00:00
# 2022-10-08 00:00:00
# 2022-11-06 00:00:00
# 2022-10-13 00:00:00
# 2022-11-11 00:00:00
# 2022-10-18 00:00:00
# 2022-11-16 00:00:00
# 2022-10-23 00:00:00
# 2022-11-21 00:00:00
# 2022-10-28 00:00:00
# 2022-11-26 00:00:00
# 2022-11-02 00:00:00
# 2022-12-01 00:00:00
# 2022-11-07 00:00:00
# 2022-12-06 00:00:00
# 2022-11-12 00:00:00
# 2022-12-11 00:00:00
# 2022-11-17 00:00:00
# 2022-12-16 00:00:00
# 2022-11-22 00:00:00
# 2022-12-21 00:00:00
# 2022-11-27 00:00:00
# 2022-12-26 00:00:00
# 2022-12-02 00:00:00
# 2022-12-31 00:00:00
# 2022-12-07 00:00:00
# 2023-01-05 00:00:00
# 2022-12-12 00:00:00
# 2023-01-10 00:00:00
# 2022-12-17 00:00:00
# 2023-01-15 00:00:00
# 2022-12-22 00:00:00
# 2023-01-20 00:00:00
# 2022-12-27 00:00:00
# 2023-01-25 00:00:00
# 2023-01-01 00:00:00
# 2023-01-30 00:00:00
# 2023-01-06 00:00:00
# 2023-02-04 00:00:00
# 2023-01-11 00:00:00
# 2023-02-09 00:00:00
# 2023-01-16 00:00:00
# 2023-02-14 00:00:00
# 2023-01-21 00:00:00
# 2023-02-19 00:00:00
# 2023-01-26 00:00:00
# 2023-02-24 00:00:00
# 2023-01-31 00:00:00
# 2023-03-01 00:00:00
# 2023-02-05 00:00:00
# 2023-03-06 00:00:00
# 2023-02-10 00:00:00
# 2023-03-11 00:00:00
# 2023-02-15 00:00:00
# 2023-03-16 00:00:00
# 2023-02-20 00:00:00
# 2023-03-21 00:00:00
# 2023-02-25 00:00:00
# 2023-03-26 00:00:00
# 2023-03-02 00:00:00
# 2023-03-31 00:00:00
# 2023-03-07 00:00:00
# 2023-04-05 00:00:00
# 2023-03-12 00:00:00
# 2023-04-10 00:00:00
# 2023-03-17 00:00:00
# 2023-04-15 00:00:00
# 2023-03-22 00:00:00
# 2023-04-20 00:00:00
# 2023-03-27 00:00:00
# 2023-04-25 00:00:00
# 2023-04-01 00:00:00
# 2023-04-30 00:00:00
# 2023-04-06 00:00:00
# 2023-05-05 00:00:00
# 2023-04-11 00:00:00
# 2023-05-10 00:00:00
# 2023-04-16 00:00:00
# 2023-05-15 00:00:00
# 2023-04-21 00:00:00
# 2023-05-20 00:00:00
# 2023-04-26 00:00:00
# 2023-05-25 00:00:00
# 2023-05-01 00:00:00
# 2023-05-30 00:00:00
# 2023-05-06 00:00:00
# 2023-06-04 00:00:00
# 2023-05-11 00:00:00
# 2023-06-09 00:00:00
# 2023-05-16 00:00:00
# 2023-06-14 00:00:00
# 2023-05-21 00:00:00
# 2023-06-19 00:00:00
# 2023-05-26 00:00:00
# 2023-06-24 00:00:00
# 2023-05-31 00:00:00
# 2023-06-29 00:00:00
# 2023-06-05 00:00:00
# 2023-07-04 00:00:00
# 2023-06-10 00:00:00
# 2023-07-09 00:00:00
# 2023-06-15 00:00:00
# 2023-07-14 00:00:00
# 2023-06-20 00:00:00
# 2023-07-19 00:00:00
# 2023-06-25 00:00:00
# 2023-07-24 00:00:00
# 2023-06-30 00:00:00
# 2023-07-29 00:00:00
# 2023-07-05 00:00:00
# 2023-08-03 00:00:00
# 2023-07-10 00:00:00
# 2023-08-08 00:00:00
# 2023-07-15 00:00:00
# 2023-08-13 00:00:00
# 2023-07-20 00:00:00
# 2023-08-18 00:00:00
# 2023-07-25 00:00:00
# 2023-08-23 00:00:00
# 2023-07-30 00:00:00
# 2023-08-28 00:00:00
# 2023-08-04 00:00:00
# 2023-09-02 00:00:00
# 2023-08-09 00:00:00
# 2023-09-07 00:00:00
# 2023-08-14 00:00:00
# 2023-09-12 00:00:00
# 2023-08-19 00:00:00
# 2023-09-17 00:00:00
# 2023-08-24 00:00:00
# 2023-09-22 00:00:00
# 2023-08-29 00:00:00
# 2023-09-27 00:00:00
# 2023-09-03 00:00:00
# 2023-10-02 00:00:00
# 2023-09-08 00:00:00
# 2023-10-07 00:00:00
# 2023-09-13 00:00:00
# 2023-10-12 00:00:00
# 2023-09-18 00:00:00
# 2023-10-17 00:00:00
# 2023-09-23 00:00:00
# 2023-10-22 00:00:00
# 2023-09-28 00:00:00
# 2023-10-27 00:00:00
# 2023-10-03 00:00:00
# 2023-11-01 00:00:00
# 2023-10-08 00:00:00
# 2023-11-06 00:00:00
# 2023-10-13 00:00:00
# 2023-11-11 00:00:00
# 2023-10-18 00:00:00
# 2023-11-16 00:00:00
# 2023-10-23 00:00:00
# 2023-11-21 00:00:00
# 2023-10-28 00:00:00
# 2023-11-26 00:00:00
# 2023-11-02 00:00:00
# 2023-12-01 00:00:00
# 2023-11-07 00:00:00
# 2023-12-06 00:00:00
# 2023-11-12 00:00:00
# 2023-12-11 00:00:00
# 2023-11-17 00:00:00
# 2023-12-16 00:00:00
# 2023-11-22 00:00:00
# 2023-12-21 00:00:00
# 2023-11-27 00:00:00
# 2023-12-26 00:00:00
# 2023-12-02 00:00:00
# 2023-12-31 00:00:00
# 2023-12-07 00:00:00
# 2024-01-05 00:00:00
# 2023-12-12 00:00:00
# 2024-01-10 00:00:00
# 2023-12-17 00:00:00
# 2024-01-15 00:00:00
# 2023-12-22 00:00:00
# 2024-01-20 00:00:00
# 2023-12-27 00:00:00
# 2024-01-25 00:00:00
# 2024-01-01 00:00:00
# 2024-01-30 00:00:00
# 2024-01-06 00:00:00
# 2024-02-04 00:00:00
# 2024-01-11 00:00:00
# 2024-02-09 00:00:00
# 2024-01-16 00:00:00
# 2024-02-12 00:00:00
# 2024-01-21 00:00:00
# 2024-02-12 00:00:00
# 2024-01-26 00:00:00
# 2024-02-12 00:00:00
# 2024-01-31 00:00:00
# 2024-02-12 00:00:00
# 2024-02-05 00:00:00
# 2024-02-12 00:00:00
# 2024-02-10 00:00:00
# 2024-02-12 00:00:00

# %%
xs_coeffs[['coef_carry_weight','coef_momo_weight','coef_breakout_weight']].plot(figsize=(10,4),title='Rolling linear model coefficients')
# Out:
# <AxesSubplot: title={'center': 'Rolling linear model coefficients'}, xlabel='date'>

# %% [markdown]
# ## Blending Coefficients into Weights

# %%
exp_return_df['combined_weight'] = (exp_return_df['carry_weight'] * exp_return_df['coef_carry_weight'] +
                                       exp_return_df['momo_weight'] * exp_return_df['coef_momo_weight'] +
                                       exp_return_df['breakout'] * exp_return_df['coef_breakout_weight']+
                                         exp_return_df['xs_intercept']   )



exp_return_df = exp_return_df.groupby('date').apply(lambda x:x.assign(scaled_weight = np.where(x.combined_weight==0,0,x.combined_weight/x.combined_weight.abs().sum())))

# %%
exp_return_df['port_rets'] = exp_return_df.log_rets* exp_return_df.scaled_weight
exp_return_df.groupby('date').port_rets.sum().cumsum().plot(figsize=(12,4))

plt.title('Combined Carry, Momentum, and Breakout Model on top 30 perps by volume')
plt.xlabel('')
plt.ylabel('Cumulative return')
# Out:
# Text(0, 0.5, 'Cumulative return')

# %%
weights_plot = (
    exp_return_df
    .groupby('date').scaled_weight
    .sum()
)

weights_plot.plot(figsize=(12,4))
# Set labels and title
plt.xlabel('Date')
plt.ylabel('Portfolio net weight')
plt.title('Portfolio Net Weight Over Time')
# Out:
# Text(0.5, 1.0, 'Portfolio Net Weight Over Time')

# %%
exp_return_df.to_pickle('exp_return_df.pkl')
